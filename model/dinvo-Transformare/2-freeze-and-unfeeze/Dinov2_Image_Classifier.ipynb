# %%
# Import Packages
import numpy as np
import torch
import torchvision.transforms as T
from PIL import Image
import os
import json
import glob
from tqdm.notebook import tqdm
from sklearn import svm
from sklearn.metrics import accuracy_score, classification_report, top_k_accuracy_score
import matplotlib.pyplot as plt
from google.colab import drive
import joblib

# %%
# Mount Google Drive (if your dataset is stored there)
drive.mount('/content/drive')

# Define paths to dataset
train_path = "/content/drive/MyDrive/AML/Data/Train/"  # Update this path
test_path = "/content/drive/MyDrive/AML/Data/Test/"  # Update this path
# Out:
# Mounted at /content/drive

# %%
# Load Dataset and Create Labels Dictionary
cwd = os.getcwd()
ROOT_DIR = train_path

labels = {}
for folder in os.listdir(ROOT_DIR):
    for file in os.listdir(os.path.join(ROOT_DIR, folder)):
        if file.endswith(".jpg"):
            full_name = os.path.join(ROOT_DIR, folder, file)
            labels[full_name] = folder

files = list(labels.keys())

# %%
# Load DINOv2 Model and Compute Embeddings
dinov2_vits14 = torch.hub.load("facebookresearch/dinov2", "dinov2_vits14")
device = torch.device('cuda' if torch.cuda.is_available() else "cpu")
dinov2_vits14.to(device)
# Out:
# Downloading: "https://github.com/facebookresearch/dinov2/zipball/main" to /root/.cache/torch/hub/main.zip
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /root/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vits14/dinov2_vits14_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vits14_pretrain.pth
# 100%|██████████| 84.2M/84.2M [00:00<00:00, 205MB/s]
# DinoVisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 384, kernel_size=(14, 14), stride=(14, 14))
#     (norm): Identity()
#   )
#   (blocks): ModuleList(
#     (0-11): 12 x NestedTensorBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): MemEffAttention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#   (head): Identity()
# )

# %%
# Fine-Tune the DINOv2 Model
for param in dinov2_vits14.parameters():
    param.requires_grad = False  # Freeze all layers

# Optionally, unfreeze the last few layers for fine-tuning:
for param in list(dinov2_vits14.parameters())[-5:]:
    param.requires_grad = True

# %%
print(dinov2_vits14)  # Print the DINOv2 model architecture
# Out:
# DinoVisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 384, kernel_size=(14, 14), stride=(14, 14))
#     (norm): Identity()
#   )
#   (blocks): ModuleList(
#     (0-11): 12 x NestedTensorBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): MemEffAttention(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): LayerScale()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): LayerScale()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#   (head): Identity()
# )

# %%
# Define Transformation for Images
transform_image = T.Compose([
    T.ToTensor(),
    T.Resize(224),
    T.Normalize([0.5], [0.5])
])

# %%
def load_image(img: str) -> torch.Tensor:
    """
    Load an image and return a tensor that can be used as an input to DINOv2.
    """
    img = Image.open(img)
    transformed_img = transform_image(img)[:3].unsqueeze(0)
    return transformed_img

# %%
def compute_embeddings(files: list) -> dict:
    """
    Create an index that contains all of the images in the specified list of files.
    """
    all_embeddings = {}

    with torch.no_grad():
        for i, file in enumerate(tqdm(files)):
            embeddings = dinov2_vits14(load_image(file).to(device))
            all_embeddings[file] = np.array(embeddings[0].cpu().numpy()).reshape(1, -1).tolist()

    with open("all_embeddings.json", "w") as f:
        f.write(json.dumps(all_embeddings))

    return all_embeddings

# Compute Embeddings
embeddings = compute_embeddings(files)
# Out:
#   0%|          | 0/4829 [00:00<?, ?it/s]

# %%
# Train SVM Classifier
clf = svm.SVC(gamma='scale')
y = [labels[file] for file in files]
embedding_list = list(embeddings.values())

# Train SVM Classifier
clf.fit(np.array(embedding_list).reshape(-1, 384), y)
# Out:
# SVC()

# %%
# Evaluation Metrics
def evaluate_model(clf, embeddings, labels, files):
    y_true = [labels[file] for file in files]
    y_pred = []
    y_pred_proba = []

    with torch.no_grad():
        for file in tqdm(files):
            embedding = dinov2_vits14(load_image(file).to(device))
            prediction = clf.predict(np.array(embedding[0].cpu()).reshape(1, -1))
            y_pred.append(prediction[0])

    # Calculate Top-1 Accuracy
    top1_accuracy = accuracy_score(y_true, y_pred)
    print(f"Top-1 Accuracy: {top1_accuracy}")

    # Calculate Average Accuracy per Class
    report = classification_report(y_true, y_pred, output_dict=True)
    avg_per_class = np.mean([report[label]['recall'] for label in set(y_true)])
    print(f"Average Accuracy per Class: {avg_per_class}")

    # Calculate Top-5 Accuracy (Assuming Top-5 probability scores are available)
    # Placeholder for Top-5 implementation
    # top5_accuracy = top_k_accuracy_score(y_true, y_pred_proba, k=5)
    # print(f"Top-5 Accuracy: {top5_accuracy}")

    # Plot per-class accuracy
    class_accuracies = [report[label]['recall'] for label in set(y_true)]
    classes = list(set(y_true))
    plt.figure(figsize=(10, 6))
    plt.bar(classes, class_accuracies)
    plt.xlabel('Classes')
    plt.ylabel('Accuracy')
    plt.title('Accuracy per Class')
    plt.xticks(rotation=90)
    plt.show()

# Evaluate Model
evaluate_model(clf, embeddings, labels, files)
# Out:
#   0%|          | 0/4829 [00:00<?, ?it/s]
# Top-1 Accuracy: 0.9842617519155105
# Average Accuracy per Class: 0.9834941309577994

# %%
# Evaluate Model on Test Data
def evaluate_test_model(clf, test_path):
    test_labels = {}
    test_files = []
    for folder in os.listdir(test_path):
        for file in os.listdir(os.path.join(test_path, folder)):
            if file.endswith(".jpg"):
                full_name = os.path.join(test_path, folder, file)
                test_labels[full_name] = folder
                test_files.append(full_name)

    evaluate_model(clf, compute_embeddings(test_files), test_labels, test_files)

# Run Evaluation on Test Data
evaluate_test_model(clf, test_path)
# Out:
#   0%|          | 0/1204 [00:00<?, ?it/s]
#   0%|          | 0/1204 [00:00<?, ?it/s]
# Top-1 Accuracy: 0.8264119601328903
# Average Accuracy per Class: 0.8217857142857143

# %%
# Evaluate accuracy per class on the test data without running the complete evaluation function

# Load test dataset
test_labels = {}
test_files = []
for folder in os.listdir(test_path):
    for file in os.listdir(os.path.join(test_path, folder)):
        if file.endswith(".jpg"):
            full_name = os.path.join(test_path, folder, file)
            test_labels[full_name] = folder
            test_files.append(full_name)

# Compute embeddings for test files
test_embeddings = compute_embeddings(test_files)

# Generate predictions for the test files
y_true = [test_labels[file] for file in test_files]
y_pred = []

with torch.no_grad():
    for file in tqdm(test_files):
        embedding = dinov2_vits14(load_image(file).to(device))
        prediction = clf.predict(np.array(embedding[0].cpu()).reshape(1, -1))
        y_pred.append(prediction[0])

# Calculate and print accuracy per class in list form
report = classification_report(y_true, y_pred, output_dict=True)
class_accuracies = [report[label]['recall'] for label in set(y_true)]
classes = list(set(y_true))

# Print per-class accuracy in list form
for cls, acc in zip(classes, class_accuracies):
    print(f"Class: {cls}, Accuracy: {acc}")

# Plot accuracy per class
plt.figure(figsize=(10, 6))
plt.bar(classes, class_accuracies)
plt.xlabel('Classes')
plt.ylabel('Accuracy')
plt.title('Accuracy per Class')
plt.xticks(rotation=90)
plt.show()
# Out:
#   0%|          | 0/1204 [00:00<?, ?it/s]
#   0%|          | 0/1204 [00:00<?, ?it/s]
# Class: Artic_Tern, Accuracy: 0.5714285714285714
# Class: Blue_winged_Warbler, Accuracy: 0.8571428571428571
# Class: Kentucky_Warbler, Accuracy: 0.8333333333333334
# Class: Boat_tailed_Grackle, Accuracy: 0.8571428571428571
# Class: Ovenbird, Accuracy: 1.0
# Class: Belted_Kingfisher, Accuracy: 0.5
# Class: Evening_Grosbeak, Accuracy: 0.8
# Class: Henslow_Sparrow, Accuracy: 0.7142857142857143
# Class: Rose_breasted_Grosbeak, Accuracy: 0.75
# Class: Sage_Thrasher, Accuracy: 1.0
# Class: American_Redstart, Accuracy: 0.6666666666666666
# Class: Spotted_Catbird, Accuracy: 1.0
# Class: Cactus_Wren, Accuracy: 0.8
# Class: White_breasted_Kingfisher, Accuracy: 1.0
# Class: Geococcyx, Accuracy: 1.0
# Class: Gray_crowned_Rosy_Finch, Accuracy: 1.0
# Class: Scott_Oriole, Accuracy: 1.0
# Class: Mallard, Accuracy: 1.0
# Class: Yellow_headed_Blackbird, Accuracy: 1.0
# Class: Hooded_Merganser, Accuracy: 0.8571428571428571
# Class: Harris_Sparrow, Accuracy: 0.8
# Class: Green_Kingfisher, Accuracy: 1.0
# Class: Brown_Pelican, Accuracy: 1.0
# Class: Gadwall, Accuracy: 1.0
# Class: Parakeet_Auklet, Accuracy: 1.0
# Class: Red_winged_Blackbird, Accuracy: 0.8
# Class: Golden_winged_Warbler, Accuracy: 1.0
# Class: Rufous_Hummingbird, Accuracy: 1.0
# Class: White_necked_Raven, Accuracy: 1.0
# Class: Tree_Sparrow, Accuracy: 0.75
# Class: Great_Grey_Shrike, Accuracy: 0.5
# Class: Horned_Lark, Accuracy: 1.0
# Class: Indigo_Bunting, Accuracy: 1.0
# Class: Tennessee_Warbler, Accuracy: 0.6666666666666666
# Class: Pacific_Loon, Accuracy: 1.0
# Class: Winter_Wren, Accuracy: 0.7142857142857143
# Class: Vermilion_Flycatcher, Accuracy: 1.0
# Class: Sooty_Albatross, Accuracy: 0.8
# Class: Downy_Woodpecker, Accuracy: 0.875
# Class: Pileated_Woodpecker, Accuracy: 1.0
# Class: White_crowned_Sparrow, Accuracy: 0.4
# Class: White_eyed_Vireo, Accuracy: 0.7142857142857143
# Class: Palm_Warbler, Accuracy: 0.6666666666666666
# Class: Wilson_Warbler, Accuracy: 0.7142857142857143
# Class: Swainson_Warbler, Accuracy: 0.4
# Class: Blue_Jay, Accuracy: 0.7142857142857143
# Class: Baltimore_Oriole, Accuracy: 0.8
# Class: Frigatebird, Accuracy: 1.0
# Class: Gray_Kingbird, Accuracy: 1.0
# Class: Red_breasted_Merganser, Accuracy: 1.0
# Class: Loggerhead_Shrike, Accuracy: 0.8571428571428571
# Class: Cliff_Swallow, Accuracy: 1.0
# Class: Brewer_Blackbird, Accuracy: 0.6
# Class: Western_Wood_Pewee, Accuracy: 0.7142857142857143
# Class: Northern_Fulmar, Accuracy: 0.8333333333333334
# Class: Brewer_Sparrow, Accuracy: 0.7142857142857143
# Class: Prothonotary_Warbler, Accuracy: 0.8571428571428571
# Class: Yellow_bellied_Flycatcher, Accuracy: 0.7142857142857143
# Class: Glaucous_winged_Gull, Accuracy: 0.5714285714285714
# Class: Nashville_Warbler, Accuracy: 1.0
# Class: Bohemian_Waxwing, Accuracy: 0.8571428571428571
# Class: Scarlet_Tanager, Accuracy: 1.0
# Class: Canada_Warbler, Accuracy: 1.0
# Class: Seaside_Sparrow, Accuracy: 0.6
# Class: Bobolink, Accuracy: 1.0
# Class: Barn_Swallow, Accuracy: 1.0
# Class: Cerulean_Warbler, Accuracy: 1.0
# Class: Chipping_Sparrow, Accuracy: 0.3333333333333333
# Class: Anna_Hummingbird, Accuracy: 0.8
# Class: Acadian_Flycatcher, Accuracy: 0.5714285714285714
# Class: Bronzed_Cowbird, Accuracy: 0.8
# Class: Northern_Waterthrush, Accuracy: 1.0
# Class: Dark_eyed_Junco, Accuracy: 1.0
# Class: Orange_crowned_Warbler, Accuracy: 0.8333333333333334
# Class: Yellow_billed_Cuckoo, Accuracy: 0.42857142857142855
# Class: Great_Crested_Flycatcher, Accuracy: 1.0
# Class: American_Goldfinch, Accuracy: 0.8
# Class: Caspian_Tern, Accuracy: 1.0
# Class: Western_Grebe, Accuracy: 1.0
# Class: Pelagic_Cormorant, Accuracy: 0.8333333333333334
# Class: Mangrove_Cuckoo, Accuracy: 0.6666666666666666
# Class: Cape_May_Warbler, Accuracy: 0.8571428571428571
# Class: Tropical_Kingbird, Accuracy: 0.8571428571428571
# Class: Least_Auklet, Accuracy: 1.0
# Class: Northern_Flicker, Accuracy: 0.75
# Class: Eastern_Towhee, Accuracy: 0.8333333333333334
# Class: Pied_billed_Grebe, Accuracy: 0.8333333333333334
# Class: Black_billed_Cuckoo, Accuracy: 0.5714285714285714
# Class: Mockingbird, Accuracy: 0.6666666666666666
# Class: Crested_Auklet, Accuracy: 1.0
# Class: Black_capped_Vireo, Accuracy: 0.8
# Class: Brandt_Cormorant, Accuracy: 0.6
# Class: Brown_Thrasher, Accuracy: 1.0
# Class: White_throated_Sparrow, Accuracy: 1.0
# Class: Elegant_Tern, Accuracy: 0.4
# Class: Louisiana_Waterthrush, Accuracy: 0.3333333333333333
# Class: Savannah_Sparrow, Accuracy: 0.5714285714285714
# Class: Nighthawk, Accuracy: 1.0
# Class: Shiny_Cowbird, Accuracy: 1.0
# Class: Marsh_Wren, Accuracy: 1.0
# Class: Sayornis, Accuracy: 0.8
# Class: Carolina_Wren, Accuracy: 1.0
# Class: American_Crow, Accuracy: 0.4
# Class: Lazuli_Bunting, Accuracy: 0.5
# Class: Cardinal, Accuracy: 1.0
# Class: Ring_billed_Gull, Accuracy: 0.4
# Class: Clay_colored_Sparrow, Accuracy: 0.5714285714285714
# Class: Scissor_tailed_Flycatcher, Accuracy: 1.0
# Class: Worm_eating_Warbler, Accuracy: 0.3333333333333333
# Class: American_Three_toed_Woodpecker, Accuracy: 1.0
# Class: Least_Flycatcher, Accuracy: 0.16666666666666666
# Class: Gray_Catbird, Accuracy: 1.0
# Class: Tree_Swallow, Accuracy: 0.7142857142857143
# Class: Black_Tern, Accuracy: 0.75
# Class: Red_legged_Kittiwake, Accuracy: 0.75
# Class: Green_Violetear, Accuracy: 1.0
# Class: Black_footed_Albatross, Accuracy: 0.8571428571428571
# Class: Green_tailed_Towhee, Accuracy: 1.0
# Class: Orchard_Oriole, Accuracy: 0.7142857142857143
# Class: Chestnut_sided_Warbler, Accuracy: 1.0
# Class: Rock_Wren, Accuracy: 1.0
# Class: Black_and_white_Warbler, Accuracy: 1.0
# Class: Groove_billed_Ani, Accuracy: 1.0
# Class: Rhinoceros_Auklet, Accuracy: 1.0
# Class: Ringed_Kingfisher, Accuracy: 1.0
# Class: Western_Meadowlark, Accuracy: 0.6666666666666666
# Class: Pomarine_Jaeger, Accuracy: 0.8333333333333334
# Class: Summer_Tanager, Accuracy: 0.75
# Class: Yellow_throated_Vireo, Accuracy: 1.0
# Class: Olive_sided_Flycatcher, Accuracy: 0.6666666666666666
# Class: Yellow_Warbler, Accuracy: 0.5
# Class: Magnolia_Warbler, Accuracy: 0.8
# Class: Bewick_Wren, Accuracy: 0.7142857142857143
# Class: Pine_Warbler, Accuracy: 0.8333333333333334
# Class: Fish_Crow, Accuracy: 0.6666666666666666
# Class: Philadelphia_Vireo, Accuracy: 0.7142857142857143
# Class: House_Sparrow, Accuracy: 1.0
# Class: Least_Tern, Accuracy: 0.6
# Class: Red_bellied_Woodpecker, Accuracy: 1.0
# Class: Warbling_Vireo, Accuracy: 0.8571428571428571
# Class: Eared_Grebe, Accuracy: 1.0
# Class: European_Goldfinch, Accuracy: 1.0
# Class: Red_eyed_Vireo, Accuracy: 0.8571428571428571
# Class: Cedar_Waxwing, Accuracy: 0.5714285714285714
# Class: Black_throated_Blue_Warbler, Accuracy: 1.0
# Class: Yellow_breasted_Chat, Accuracy: 1.0
# Class: Green_Jay, Accuracy: 0.8571428571428571
# Class: Mourning_Warbler, Accuracy: 0.8571428571428571
# Class: Red_cockaded_Woodpecker, Accuracy: 0.75
# Class: Song_Sparrow, Accuracy: 0.625
# Class: Fox_Sparrow, Accuracy: 0.8571428571428571
# Class: Florida_Jay, Accuracy: 0.8571428571428571
# Class: Grasshopper_Sparrow, Accuracy: 0.8571428571428571
# Class: Myrtle_Warbler, Accuracy: 0.75
# Class: Ivory_Gull, Accuracy: 0.75
# Class: Horned_Puffin, Accuracy: 1.0
# Class: Cape_Glossy_Starling, Accuracy: 1.0
# Class: Lincoln_Sparrow, Accuracy: 1.0
# Class: Common_Raven, Accuracy: 0.6
# Class: White_Pelican, Accuracy: 1.0
# Class: Common_Yellowthroat, Accuracy: 0.8
# Class: Nelson_Sharp_tailed_Sparrow, Accuracy: 0.8333333333333334
# Class: Forsters_Tern, Accuracy: 1.0
# Class: Purple_Finch, Accuracy: 0.8333333333333334
# Class: Horned_Grebe, Accuracy: 0.8333333333333334
# Class: Le_Conte_Sparrow, Accuracy: 1.0
# Class: Common_Tern, Accuracy: 0.14285714285714285
# Class: Pied_Kingfisher, Accuracy: 1.0
# Class: Clark_Nutcracker, Accuracy: 1.0
# Class: Herring_Gull, Accuracy: 0.2
# Class: Black_throated_Sparrow, Accuracy: 1.0
# Class: Hooded_Warbler, Accuracy: 1.0
# Class: Red_headed_Woodpecker, Accuracy: 0.8333333333333334
# Class: Whip_poor_Will, Accuracy: 0.75
# Class: Rusty_Blackbird, Accuracy: 0.8
# Class: Pine_Grosbeak, Accuracy: 1.0
# Class: Western_Gull, Accuracy: 0.5
# Class: White_breasted_Nuthatch, Accuracy: 1.0
# Class: House_Wren, Accuracy: 0.6
# Class: Bank_Swallow, Accuracy: 0.6
# Class: Field_Sparrow, Accuracy: 0.8333333333333334
# Class: Baird_Sparrow, Accuracy: 0.8571428571428571
# Class: Laysan_Albatross, Accuracy: 1.0
# Class: Blue_Grosbeak, Accuracy: 1.0
# Class: Chuck_will_Widow, Accuracy: 0.5
# Class: California_Gull, Accuracy: 0.6
# Class: Brown_Creeper, Accuracy: 1.0
# Class: Painted_Bunting, Accuracy: 1.0
# Class: Red_faced_Cormorant, Accuracy: 0.5
# Class: Pigeon_Guillemot, Accuracy: 1.0
# Class: Long_tailed_Jaeger, Accuracy: 1.0
# Class: Hooded_Oriole, Accuracy: 0.8571428571428571
# Class: Slaty_backed_Gull, Accuracy: 0.6666666666666666
# Class: Blue_headed_Vireo, Accuracy: 0.7142857142857143
# Class: Bay_breasted_Warbler, Accuracy: 1.0
# Class: American_Pipit, Accuracy: 1.0
# Class: Heermann_Gull, Accuracy: 1.0
# Class: Prairie_Warbler, Accuracy: 0.5714285714285714
# Class: Ruby_throated_Hummingbird, Accuracy: 0.8
# Class: Vesper_Sparrow, Accuracy: 1.0

# %%
# Classify an Image
input_file = "/content/drive/MyDrive/AML/Data/Test/Acadian_Flycatcher/0209.jpg"
if os.path.exists(input_file):
    new_image = load_image(input_file)

    plt.imshow(Image.open(input_file))
    plt.axis('off')
    plt.show()

    with torch.no_grad():
        embedding = dinov2_vits14(new_image.to(device))
        prediction = clf.predict(np.array(embedding[0].cpu()).reshape(1, -1))

    print("Predicted class: " + prediction[0])
else:
    print(f"Error: The file {input_file} does not exist. Please provide a valid image path.")
# Out:
# Predicted class: Acadian_Flycatcher

# %%
# Save the trained model
joblib.dump(clf, '/content/drive/MyDrive/AML/dinov2_image_classifier_model.pkl')
# Out:
# ['/content/drive/MyDrive/AML/dinov2_image_classifier_model.pkl']
